# %%
from math import calculate_correlation

# Calculate the correlation between GDP and Health Factors
calculate_correlation("DataSet/GroupD_DataSet.csv", "GDP (USD)", "Life Expectancy (in age)", 0.05)
calculate_correlation("DataSet/GroupD_DataSet.csv", "GDP (USD)", "Adult Mortality (%)", 0.05)
calculate_correlation("DataSet/GroupD_DataSet.csv", "GDP (USD)", "Hepatitis B (%)", 0.05)
calculate_correlation("DataSet/GroupD_DataSet.csv", "GDP (USD)", "Food Safety IHR (%)", 0.05)

# Calculate the correlation between Schooling and Health Factors
calculate_correlation("DataSet/GroupD_DataSet.csv", "Schooling (Yrs)", "Life Expectancy (in age)", 0.05)
calculate_correlation("DataSet/GroupD_DataSet.csv", "Schooling (Yrs)", "Adult Mortality (%)", 0.05)
calculate_correlation("DataSet/GroupD_DataSet.csv", "Schooling (Yrs)", "Hepatitis B (%)", 0.05)
calculate_correlation("DataSet/GroupD_DataSet.csv", "Schooling (Yrs)", "Food Safety IHR (%)", 0.05)

# Calculate the correlation between Status and Health Factors
calculate_correlation("DataSet/GroupD_DataSet.csv", "Status", "Life Expectancy (in age)", 0.05)
calculate_correlation("DataSet/GroupD_DataSet.csv", "Status", "Adult Mortality (%)", 0.05)
calculate_correlation("DataSet/GroupD_DataSet.csv", "Status", "Hepatitis B (%)", 0.05)
calculate_correlation("DataSet/GroupD_DataSet.csv", "Status", "Food Safety IHR (%)", 0.05)
# Out:
# Calculating correlation between 'GDP (USD)' and 'Life Expectancy (in age)' with alpha = 0.05
# Correlation coefficient: 0.4544910133998906
# P-value: 3.2027818561867573e-09
# Significant correlation: True
# ----------------------------------------
# Calculating correlation between 'GDP (USD)' and 'Adult Mortality (%)' with alpha = 0.05
# Correlation coefficient: -0.3358696403850731
# P-value: 2.0585033808954795e-05
# Significant correlation: True
# ----------------------------------------
# Calculating correlation between 'GDP (USD)' and 'Hepatitis B (%)' with alpha = 0.05
# Correlation coefficient: 0.14211629218732194
# P-value: 0.08705641598880176
# Significant correlation: False
# ----------------------------------------
# Calculating correlation between 'GDP (USD)' and 'Food Safety IHR (%)' with alpha = 0.05
# Correlation coefficient: 0.36668708611186274
# P-value: 3.92702578650525e-06
# Significant correlation: True
# ----------------------------------------
# Calculating correlation between 'Schooling (Yrs)' and 'Life Expectancy (in age)' with alpha = 0.05
# Correlation coefficient: 0.8181594367888723
# P-value: 5.926952626765663e-43
# Significant correlation: True
# ----------------------------------------
# Calculating correlation between 'Schooling (Yrs)' and 'Adult Mortality (%)' with alpha = 0.05
# Correlation coefficient: -0.5461781805958297
# P-value: 7.711590507953583e-15
# Significant correlation: True
# ----------------------------------------
# Calculating correlation between 'Schooling (Yrs)' and 'Hepatitis B (%)' with alpha = 0.05
# Correlation coefficient: 0.33405088921126913
# P-value: 1.1600021575971176e-05
# Significant correlation: True
# ----------------------------------------
# Calculating correlation between 'Schooling (Yrs)' and 'Food Safety IHR (%)' with alpha = 0.05
# Correlation coefficient: 0.6265934867862444
# P-value: 1.0413342134139609e-19
# Significant correlation: True
# ----------------------------------------
# Calculating correlation between 'Status' and 'Life Expectancy (in age)' with alpha = 0.05
# Found strings in Status with 2 unique strings and Developing = 0, Developed = 1
# Correlation coefficient: 0.5166570632491246
# P-value: 7.05386662357887e-14
# Significant correlation: True
# ----------------------------------------
# Calculating correlation between 'Status' and 'Adult Mortality (%)' with alpha = 0.05
# Found strings in Status with 2 unique strings and Developing = 0, Developed = 1
# Correlation coefficient: -0.3690024500922719
# P-value: 2.745461340553058e-07
# Significant correlation: True
# ----------------------------------------
# Calculating correlation between 'Status' and 'Hepatitis B (%)' with alpha = 0.05
# Found strings in Status with 2 unique strings and Developing = 0, Developed = 1
# Correlation coefficient: 0.12238755982911301
# P-value: 0.107655596189469
# Significant correlation: False
# ----------------------------------------
# Calculating correlation between 'Status' and 'Food Safety IHR (%)' with alpha = 0.05
# Found strings in Status with 2 unique strings and Developing = 0, Developed = 1
# Correlation coefficient: 0.4149936635361955
# P-value: 9.294718725713741e-09
# Significant correlation: True
# ----------------------------------------
# (np.float64(0.4149936635361955),
#  np.float64(9.294718725713741e-09),
#       Unnamed: 0                             Country  Food Safety IHR (%)  \
#  0             0                         Afghanistan                 20.0
#  1             1                             Albania                100.0
#  2             2                             Algeria                 80.0
#  3             3                              Angola                 40.0
#  4             4                 Antigua and Barbuda                 80.0
#  ..          ...                                 ...                  ...
#  178         178  Venezuela (Bolivarian Republic of)                 80.0
#  179         179                            Viet Nam                 40.0
#  180         180                               Yemen                 40.0
#  181         181                              Zambia                 80.0
#  182         182                            Zimbabwe                 80.0
#
#       Status  Life Expectancy (in age)  Adult Mortality (%)  Hepatitis B (%)  \
#  0         0                      65.0                 26.3             65.0
#  1         0                      77.8                  7.4             99.0
#  2         0                      75.6                  1.9             95.0
#  3         0                      52.4                 33.5             64.0
#  4         0                      76.4                  1.3             99.0
#  ..      ...                       ...                  ...              ...
#  178       0                      74.1                 15.7             87.0
#  179       0                      76.0                 12.7             97.0
#  180       0                      65.7                 22.4             69.0
#  181       0                      61.8                  3.3              9.0
#  182       0                      67.0                 33.6             87.0
#
#          GDP (USD)  Schooling (Yrs)
#  0      584.259210             10.1
#  1     3954.227830             14.2
#  2     4132.762920             14.4
#  3     3695.793748             11.4
#  4    13566.954100             13.9
#  ..            ...              ...
#  178           NaN             14.3
#  179           NaN             12.6
#  180           NaN              9.0
#  181   1313.889646             12.5
#  182    118.693830             10.3
#
#  [177 rows x 9 columns])
